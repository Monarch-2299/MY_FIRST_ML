# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('data\DM_data_set.csv')

# %%
df
# Out:
#        Unnamed: 0  PatientID  Pregnancies  PlasmaGlucose  \
# 0               0    1354778            0            171
# 1               1    1147438            8             92
# 2               2    1640031            7            115
# 3               3    1883350            9            103
# 4               4    1424119            1             85
# ...           ...        ...          ...            ...
# 14995       14995    1490300           10             65
# 14996       14996    1744410            2             73
# 14997       14997    1742742            0             93
# 14998       14998    1099353            0            132
# 14999       14999    1386396            3            114
#
#        DiastolicBloodPressure  TricepsThickness  SerumInsulin        BMI  \
# 0                          80                34            23  43.509726
# 1                          93                47            36  21.240576
# ...

# %%
df.isna().sum()
# Out:
# Unnamed: 0                0
# PatientID                 0
# Pregnancies               0
# PlasmaGlucose             0
# DiastolicBloodPressure    0
# TricepsThickness          0
# SerumInsulin              0
# BMI                       0
# DiabetesPedigree          0
# Age                       0
# Diabetic                  0
# dtype: int64
